# %%
import sys
import pandas as pd
import numpy as np
import os
from sklearn.metrics import accuracy_score,precision_score,recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from feature_engine import imputation as mdi
from feature_engine import encoding as ce
import warnings
warnings.filterwarnings('ignore')


def get_path():
    cur_path = os.getcwd()
    parent_path = os.path.dirname(cur_path)
    return cur_path, parent_path


def file_path(data_path, file):
    return os.path.abspath(os.path.join(data_path, f'{file}'))


def df_write(data_path, df, file):
    df = df.copy()
    df.to_csv(os.path.abspath(os.path.join(data_path, file)), index=False)


def split_train_test(df, configs):
    df = df.copy()
    X = df.drop(columns=configs['y_col'][0])
    y = df[configs['y_col'][0]]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=configs['y_col'][0])
    return X_train, X_test, y_train, y_test


def model_selection(option='logistic'):
    if option == 'LGBM':
        return lgb.LGBMClassifier(random_state=0)
    else:
        return LogisticRegression(random_state=0)


def read_data(configs):
    if configs['date_col'][0] == ' ':
        df = pd.read_csv(configs['file_name'][0])
    else:
        df = pd.read_csv(configs['file_name'][0], parse_dates=configs['date_col'])

    if configs['remove_col'][0] == ' ':
        pass
    else:
        if configs['remove_col'][0] in df.columns.to_list():
            df = df.drop(configs['remove_col'][0], axis=1)

    return df


def y_label_enc(df, configs):
    df = df.copy()
    Y_col = configs['y_col'][0]
    if df[Y_col].isnull().any():
        Y_null = True
    else:
        Y_null = False
    labeler = LabelEncoder()
    df[Y_col] = labeler.fit_transform(df[Y_col])
    return df, Y_null


def organize_data(df, configs, y_null):
    df = df.copy()
    cols = df.columns.to_list()
    null_threshhold_cols = []
    no_null_cols = []
    date_time = configs['date_col']
    Y_col = configs['y_col'][0]

    for col in cols:
        null_mean = df[col].isnull().mean()
        if null_mean >= configs['null_threshhold'][0]:
            null_threshhold_cols.append(col)
        if null_mean == 0:
            no_null_cols.append(col)

    cols_stayed = [item for item in cols if item not in null_threshhold_cols]
    data = df[cols_stayed].copy()

    # numerical: discrete vs continuous
    discrete = [var for var in cols_stayed if
                data[var].dtype != 'O' and var != Y_col and var not in date_time and data[var].nunique() < 10]
    continuous = [var for var in cols_stayed if
                  data[var].dtype != 'O' and var != Y_col and var not in date_time and var not in discrete]

    # categorical
    categorical = [var for var in cols_stayed if data[var].dtype == 'O' and var != Y_col]

    print('There are {} date_time variables'.format(len(date_time)))
    print('There are {} discrete variables'.format(len(discrete)))
    print('There are {} continuous variables'.format(len(continuous)))
    print('There are {} categorical variables'.format(len(categorical)))

    if y_null:
        data = data[data[Y_col] != data[Y_col].max()].copy()
    else:
        data = data.copy()

    return data, discrete, continuous, categorical


def split_train_test(df, configs):
    df = df.copy()
    X = df.drop(columns=configs['y_col'][0])
    y = df[configs['y_col'][0]]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=configs['test_size'][0], random_state=0, stratify=y)
    return X_train, X_test, y_train, y_test


def make_imputer_pipe(continuous, discrete, categorical):
    numberImputer = continuous + discrete
    categoricalImputer = categorical

    if (len(numberImputer) > 0) & (len(categoricalImputer) > 0):
        pipe = Pipeline([
            ("median_imputer",
             mdi.MeanMedianImputer(
                 imputation_method="median", variables=numberImputer),),

            ('imputer_cat',
             mdi.CategoricalImputer(variables=categoricalImputer)),

            ('categorical_encoder',
             ce.OrdinalEncoder(encoding_method='ordered',
                               variables=categoricalImputer))
        ])
    else:
        if (len(numberImputer) > 0) & (len(categoricalImputer) == 0):
            pipe = Pipeline([
                ("median_imputer",
                 mdi.MeanMedianImputer(
                     imputation_method="median", variables=numberImputer),)
            ])
        else:
            if (len(numberImputer) == 0) & (len(categoricalImputer) > 0):
                pipe = Pipeline([
                    ('imputer_cat',
                     mdi.CategoricalImputer(variables=categoricalImputer)),

                    ('categorical_encoder',
                     ce.OrdinalEncoder(encoding_method='ordered',
                                       variables=categoricalImputer))
                ])
            else:
                pipe = []
    return pipe


def do_imputation(X_train, X_test, y_train, y_test, pipe):
    X_train, X_test, y_train, y_test = X_train.copy(), X_test.copy(), y_train.copy(), y_test.copy()
    if pipe != []:
        pipe.fit(X_train, y_train)
        X_train = pipe.transform(X_train)
        X_test = pipe.transform(X_test)
    else:
        print('no pipe applied')
    return X_train, X_test, y_train, y_test

def do_imputation_whole(df, pipe):
    df = df.copy()
    if pipe != []:
        df = pipe.fit_transform(df)        
    else:
        print('no pipe applied')
    return df


def do_train(X_train, y_train, option):
    X_train, y_train = X_train.copy(), y_train.copy()
    model = model_selection(option)
    model.fit(X_train, y_train)
    return model

    
def do_predict(model, X_test):
    return model.predict(X_test)


def min_max_scale(df):
    df = df.copy()
    scaler = MinMaxScaler()
    scaler.fit(df)
    return scaler.transform(df)


def metrics(file, y_test, pred, option, display_confusion=False, logtran=None, out_col=None):
    y_test = y_test.copy()
    pred = pred.copy()
    accuracy = round(accuracy_score(y_test, pred), 3)
    precision = round(precision_score(y_test, pred), 3)
    recall = round(recall_score(y_test, pred), 3)
    f1 = round(f1_score(y_test, pred), 3)
    print(file, option, "f1 점수:", f1, "정확도:", accuracy, "정밀도:", precision, "재현율:", recall)
    if display_confusion:        
        print(confusion_matrix(y_test, pred))
    
    scores = [file, option, logtran, out_col, f1, accuracy, precision, recall]
    cols = ['File', 'Model', 'LogTrans', 'Outliered', 'F1', 'Accuracy', 'Precision', 'Recall']
    return pd.DataFrame(data=[scores], columns=cols)


def drop_outlier(df=None, corr_highest=None, y_col=None, yes_value=None, weight=1.5):
    df = df.copy()
    targeted = df[df[y_col]==yes_value][corr_highest]
    quantile_25 = np.percentile(targeted.values, 25)
    quantile_75 = np.percentile(targeted.values, 75)

    iqr = quantile_75 - quantile_25
    iqr_weight = iqr * weight
    lowest_val = quantile_25 - iqr_weight
    highest_val = quantile_75 + iqr_weight

    outlier_index = targeted [(targeted  < lowest_val) | (targeted > highest_val)].index
    df = df.drop(outlier_index, axis=0)
    return df


def log_trans(df, trans_col):
    df = df.copy()
    trans_values = np.log1p(df[trans_col])
    df.drop([trans_col], axis=1, inplace=True)
    df.insert(0, trans_col, trans_values)
    return df


def get_skew_top3(df):
    df = df.copy()
    skewed = df.skew()
    skewed = pd.DataFrame(data=skewed).reset_index()
    idx = skewed[skewed['index']==Y_col].index
    skewed = skewed.drop(idx, axis=0)
    skewed = skewed.rename(columns={'index':'col', 0:'skewed_value'})
    skewed['abs_skewed_value'] = abs(skewed['skewed_value'])
    skewed = skewed.sort_values(by=['abs_skewed_value'], ascending=False).reset_index(drop=True)
    skewed_higher = skewed.iloc[0:3]
    return skewed_higher


def get_corr_top5(df, y_col, yes_value):
    df = df.copy()
    corr_mat = df.corr(method='pearson')
    upper_corr_mat = corr_mat.where(np.triu(np.ones(corr_mat.shape), k=1).astype(np.bool))

    # Convert to 1-D series and drop Null values
    unique_corr_pairs = upper_corr_mat.unstack().dropna()

    # Sort correlation pairs
    sorted_mat = unique_corr_pairs.sort_values()
    df_corr = pd.DataFrame(data=sorted_mat).reset_index()
    df_corr = df_corr[df_corr['level_0']==y_col]
    df_corr = df_corr.rename(columns={'level_0':'Y_col', 'level_1':'col', 0:'corr_value'})
    df_corr['abs_corr_value'] = abs(df_corr['corr_value'])
    df_corr = df_corr.sort_values(by=['abs_corr_value'], ascending=False).reset_index(drop=True)
    corr_higher = df_corr.iloc[0:5]
    return corr_higher

def split_impute_train2(file, df, configs, option='logic', logtran=None, out_col=None):
    df = df.copy()
    Y_col = configs['y_col'][0]
    
    con = df['split']=='train'
    X_train = df[con].drop(columns=['split', Y_col]) 
    y_train = df[con][Y_col]
    con = df['split']=='test'
    X_test = df[con].drop(columns=['split', Y_col]) 
    y_test = df[con][Y_col]
    
    model = do_train(X_train, y_train, option)
    pred = do_predict(model, X_test)
    result = metrics(file, y_test, pred, option, display_confusion=False, logtran=logtran, out_col=out_col)
    return result
    

def split_impute_train(df, configs, discrete, continuous, categorical, option='logic', logtran=None, out_col=None):
    X_train, X_test, y_train, y_test = split_train_test(df, configs)
    pipe = make_imputer_pipe(discrete, continuous, categorical)
    X_train, X_test, y_train, y_test = do_imputation(X_train, X_test, y_train, y_test, pipe)
    model = do_train(X_train, y_train, option)
    pred = do_predict(model, X_test)
    result = metrics(y_test, pred, option, display_confusion=False, logtran=logtran, out_col=out_col)
    return result

def pca_train_metric(df, configs, option='logic', logtran=None, out_col=None):
    df = df.copy()
    X = df.drop(columns=configs['y_col'][0])
    y = df[configs['y_col'][0]]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=configs['test_size'][0], random_state=0, stratify=y)
    model = do_train(X_train, y_train, option)
    pred = do_predict(model, X_test)
    result = metrics(y_test, pred, option, display_confusion=False, logtran=logtran, out_col=out_col)
    return result

def pca_train_metric2(file, df, configs, option='logic', logtran=None, out_col=None):
    df = df.copy()
    Y_col = configs['y_col'][0]
    
    con = df['split']=='train'
    X_train = df[con].drop(columns=['split', Y_col]) 
    y_train = df[con][Y_col]
    con = df['split']=='test'
    X_test = df[con].drop(columns=['split', Y_col]) 
    y_test = df[con][Y_col]    
    
    model = do_train(X_train, y_train, option)
    pred = do_predict(model, X_test)
    result = metrics(file, y_test, pred, option, display_confusion=False, logtran=logtran, out_col=out_col)
    return result

# %%
folder_name = 'predictive_machine'
config_file_name = 'argumet_premachine.xlsx'

cur_path = os.getcwd()
parent = os.path.abspath(os.path.join(cur_path, os.pardir))
config_file = os.path.join(parent, os.path.join('config', f'{config_file_name}'))
configs = pd.read_excel(config_file, header=None).set_index(0).T
configs = configs.to_dict('list')
ori_file_name = configs['file_name'][0]
configs['file_name'][0] = os.path.join(parent, os.path.join('data', configs['file_name'][0]))
Y_col = configs['y_col'][0]
# df_initial = read_data(configs)

# df, y_null = y_label_enc(df_initial, configs)
# df_organized, discrete, continuous, categorical = organize_data(df, configs, y_null)

files = os.listdir(os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/scaled')))
df = {}
for file in files:
    df[file] = pd.read_csv( os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/scaled', f'{file}')))

# %% [markdown]
# ### before log transformation

# %%
results = pd.DataFrame()
# result = split_impute_train(df.drop(columns=['split']), configs, discrete, continuous, categorical, option='logistic')
for file in files:
    result = split_impute_train2(file, df[file], configs, option='logistic', logtran=None, out_col=None)
    results = results.append(result)
    result = split_impute_train2(file, df[file], configs, option='LGBM', logtran=None, out_col=None)
    results = results.append(result)
results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 # result = split_impute_train(df.drop(columns=['split']), configs, discrete, continuous, categorical, option='logistic')
#       3 for file in files:
# ----> 4     result = split_impute_train2(file, df[file], configs, option='logistic', logtran=None, out_col=None)
#       5     results = results.append(result)
#       6     result = split_impute_train2(file, df[file], configs, option='LGBM', logtran=None, out_col=None)
#
# Cell In[1], line 283, in split_impute_train2(file, df, configs, option, logtran, out_col)
#     281 model = do_train(X_train, y_train, option)
#     282 pred = do_predict(model, X_test)
# --> 283 result = metrics(file, y_test, pred, option, display_confusion=False, logtran=logtran, out_col=out_col)
#     284 return result
#
# Cell In[1], line 203, in metrics(file, y_test, pred, option, display_confusion, logtran, out_col)
#     201 pred = pred.copy()
#     202 accuracy = round(accuracy_score(y_test, pred), 3)
# --> 203 precision = round(precision_score(y_test, pred), 3)
#     204 recall = round(recall_score(y_test, pred), 3)
#     205 f1 = round(f1_score(y_test, pred), 3)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1954, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1825 def precision_score(
#    1826     y_true,
#    1827     y_pred,
#    (...)
#    1833     zero_division="warn",
#    1834 ):
#    1835     """Compute the precision.
#    1836
#    1837     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1952     array([0.5, 1. , 1. ])
#    1953     """
# -> 1954     p, _, _, _ = precision_recall_fscore_support(
#    1955         y_true,
#    1956         y_pred,
#    1957         labels=labels,
#    1958         pos_label=pos_label,
#    1959         average=average,
#    1960         warn_for=("precision",),
#    1961         sample_weight=sample_weight,
#    1962         zero_division=zero_division,
#    1963     )
#    1964     return p
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %% [markdown]
# ### after log transformation

# %%
# if folder_name == 'credit':
#     trans_col = 'Amount'
# else:
#     trans_col = 'DV_pressure'

# df_log_processed = log_trans(df_organized, trans_col)
# split_impute_train(df_log_processed, configs, discrete, continuous, categorical, option='logic')



# skewed = get_skew_top3(df_initial)

for file in files:
    skewed = get_skew_top3(df[file])
    for idx, row in skewed.iterrows():
        trans_col = row[0]
        print('Logtrans 칼럼', trans_col)
        df_log_processed = log_trans(df[file], trans_col)
        result = split_impute_train2(file, df_log_processed, configs, option='logistic', logtran=trans_col, out_col=None)
        results = results.append(result)
        result = split_impute_train2(file, df_log_processed, configs, option='LGBM', logtran=trans_col, out_col=None)
        results = results.append(result)
        print()

    df_log_processed = df[file].copy()
    for idx, row in skewed.iterrows():
        trans_col = row[0]
        df_log_processed = log_trans(df_log_processed, trans_col)
    result = split_impute_train2(file, df_log_processed, configs, option='logistic', logtran='combined', out_col=None)
    results = results.append(result)
    result = split_impute_train2(file, df_log_processed, configs, option='LGBM', logtran='combined', out_col=None)
    results = results.append(result)
results
# Out:
# Logtrans 칼럼 LPS
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.722 정확도: 0.983 정밀도: 0.886 재현율: 0.609
#
# Logtrans 칼럼 Pressure_switch
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.722 정확도: 0.983 정밀도: 0.886 재현율: 0.609
#
# Logtrans 칼럼 Oil_level
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.722 정확도: 0.983 정밀도: 0.886 재현율: 0.609
#
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.722 정확도: 0.983 정밀도: 0.886 재현율: 0.609
# Logtrans 칼럼 LPS
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.621 재현율: 0.751
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.666 정확도: 0.982 정밀도: 0.941 재현율: 0.515
#
# Logtrans 칼럼 Pressure_switch
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.621 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.666 정확도: 0.982 정밀도: 0.941 재현율: 0.515
#
# Logtrans 칼럼 Oil_level
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.666 정확도: 0.982 정밀도: 0.941 재현율: 0.515
#
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.751
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.666 정확도: 0.982 정밀도: 0.941 재현율: 0.515
# Logtrans 칼럼 LPS
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.621 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.729 정확도: 0.984 정밀도: 0.927 재현율: 0.601
#
# Logtrans 칼럼 Pressure_switch
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.621 재현율: 0.749
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.729 정확도: 0.984 정밀도: 0.927 재현율: 0.601
#
# Logtrans 칼럼 Oil_level
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.62 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.729 정확도: 0.984 정밀도: 0.927 재현율: 0.601
#
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.679 정확도: 0.975 정밀도: 0.621 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.729 정확도: 0.984 정밀도: 0.927 재현율: 0.601
# Logtrans 칼럼 LPS
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.678 정확도: 0.975 정밀도: 0.619 재현율: 0.751
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.747 정확도: 0.985 정밀도: 0.947 재현율: 0.617
#
# Logtrans 칼럼 Pressure_switch
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.678 정확도: 0.975 정밀도: 0.619 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.747 정확도: 0.985 정밀도: 0.947 재현율: 0.617
#
# Logtrans 칼럼 Oil_level
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.678 정확도: 0.975 정밀도: 0.619 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.747 정확도: 0.985 정밀도: 0.947 재현율: 0.617
#
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.678 정확도: 0.975 정밀도: 0.619 재현율: 0.75
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.747 정확도: 0.985 정밀도: 0.947 재현율: 0.617
#                                         File     Model         LogTrans  \
# 0     scaled_MetroPT3(AirCompressor)_max.csv  logistic             None
# 0     scaled_MetroPT3(AirCompressor)_max.csv      LGBM             None
# 0    scaled_MetroPT3(AirCompressor)_mean.csv  logistic             None
# 0    scaled_MetroPT3(AirCompressor)_mean.csv      LGBM             None
# 0  scaled_MetroPT3(AirCompressor)_median.csv  logistic             None
# 0  scaled_MetroPT3(AirCompressor)_median.csv      LGBM             None
# 0     scaled_MetroPT3(AirCompressor)_min.csv  logistic             None
# 0     scaled_MetroPT3(AirCompressor)_min.csv      LGBM             None
# 0     scaled_MetroPT3(AirCompressor)_max.csv  logistic              LPS
# 0     scaled_MetroPT3(AirCompressor)_max.csv      LGBM              LPS
# 0     scaled_MetroPT3(AirCompressor)_max.csv  logistic  Pressure_switch
# 0     scaled_MetroPT3(AirCompressor)_max.csv      LGBM  Pressure_switch
# 0     scaled_MetroPT3(AirCompressor)_max.csv  logistic        Oil_level
# 0     scaled_MetroPT3(AirCompressor)_max.csv      LGBM        Oil_level
# 0     scaled_MetroPT3(AirCompressor)_max.csv  logistic         combined
# 0     scaled_MetroPT3(AirCompressor)_max.csv      LGBM         combined
# 0    scaled_MetroPT3(AirCompressor)_mean.csv  logistic              LPS
# 0    scaled_MetroPT3(AirCompressor)_mean.csv      LGBM              LPS
# 0    scaled_MetroPT3(AirCompressor)_mean.csv  logistic  Pressure_switch
# 0    scaled_MetroPT3(AirCompressor)_mean.csv      LGBM  Pressure_switch
# 0    scaled_MetroPT3(AirCompressor)_mean.csv  logistic        Oil_level
# 0    scaled_MetroPT3(AirCompressor)_mean.csv      LGBM        Oil_level
# 0    scaled_MetroPT3(AirCompressor)_mean.csv  logistic         combined
# 0    scaled_MetroPT3(AirCompressor)_mean.csv      LGBM         combined
# 0  scaled_MetroPT3(AirCompressor)_median.csv  logistic              LPS
# 0  scaled_MetroPT3(AirCompressor)_median.csv      LGBM              LPS
# 0  scaled_MetroPT3(AirCompressor)_median.csv  logistic  Pressure_switch
# 0  scaled_MetroPT3(AirCompressor)_median.csv      LGBM  Pressure_switch
# 0  scaled_MetroPT3(AirCompressor)_median.csv  logistic        Oil_level
# 0  scaled_MetroPT3(AirCompressor)_median.csv      LGBM        Oil_level
# 0  scaled_MetroPT3(AirCompressor)_median.csv  logistic         combined
# 0  scaled_MetroPT3(AirCompressor)_median.csv      LGBM         combined
# 0     scaled_MetroPT3(AirCompressor)_min.csv  logistic              LPS
# 0     scaled_MetroPT3(AirCompressor)_min.csv      LGBM              LPS
# 0     scaled_MetroPT3(AirCompressor)_min.csv  logistic  Pressure_switch
# 0     scaled_MetroPT3(AirCompressor)_min.csv      LGBM  Pressure_switch
# 0     scaled_MetroPT3(AirCompressor)_min.csv  logistic        Oil_level
# 0     scaled_MetroPT3(AirCompressor)_min.csv      LGBM        Oil_level
# 0     scaled_MetroPT3(AirCompressor)_min.csv  logistic         combined
# 0     scaled_MetroPT3(AirCompressor)_min.csv      LGBM         combined
#
#   Outliered     F1  Accuracy  Precision  Recall
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.722     0.983      0.886   0.609
# 0      None  0.679     0.975      0.620   0.751
# 0      None  0.666     0.982      0.941   0.515
# 0      None  0.679     0.975      0.621   0.750
# 0      None  0.729     0.984      0.927   0.601
# 0      None  0.679     0.975      0.619   0.751
# 0      None  0.747     0.985      0.947   0.617
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.722     0.983      0.886   0.609
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.722     0.983      0.886   0.609
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.722     0.983      0.886   0.609
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.722     0.983      0.886   0.609
# 0      None  0.679     0.975      0.621   0.751
# 0      None  0.666     0.982      0.941   0.515
# 0      None  0.679     0.975      0.621   0.750
# 0      None  0.666     0.982      0.941   0.515
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.666     0.982      0.941   0.515
# 0      None  0.679     0.975      0.620   0.751
# 0      None  0.666     0.982      0.941   0.515
# 0      None  0.679     0.975      0.621   0.750
# 0      None  0.729     0.984      0.927   0.601
# 0      None  0.679     0.975      0.621   0.749
# 0      None  0.729     0.984      0.927   0.601
# 0      None  0.679     0.975      0.620   0.750
# 0      None  0.729     0.984      0.927   0.601
# 0      None  0.679     0.975      0.621   0.750
# 0      None  0.729     0.984      0.927   0.601
# 0      None  0.678     0.975      0.619   0.751
# 0      None  0.747     0.985      0.947   0.617
# 0      None  0.678     0.975      0.619   0.750
# 0      None  0.747     0.985      0.947   0.617
# 0      None  0.678     0.975      0.619   0.750
# 0      None  0.747     0.985      0.947   0.617
# 0      None  0.678     0.975      0.619   0.750
# 0      None  0.747     0.985      0.947   0.617

# %% [markdown]
# ### after removing outlier with log transformation

# %%
# if folder_name == 'credit':
#     trans_col = 'Amount'
# else:
#     trans_col = 'DV_pressure'
yes_value = 1

for file in files:
    corr_higher = get_corr_top5(df[file], Y_col, yes_value)

    for idx_s, row_s in skewed.iterrows():
        trans_col = row_s[0]    
        for idx_c, row_c in corr_higher.iterrows():
            print('Logtrans 칼럼', trans_col, 'Outlier 처리 칼럼', row_c['col'], row_c['corr_value'])
            corr_highest = row_c[1]
            df_processed = log_trans(df[file], trans_col)
            df_processed = drop_outlier(df_processed, corr_highest, Y_col, yes_value, weight=1.5)
            result = split_impute_train2(file, df_processed, configs, option='logistic', logtran=trans_col, out_col=corr_highest)           
            results = results.append(result)
            result = split_impute_train2(file, df_processed, configs, option='LGBM', logtran=trans_col, out_col=corr_highest)           
            results = results.append(result)
            print()

#     for idx_s, row_s in skewed.iterrows():
#         trans_col = row_s[0]    
#         for idx_c, row_c in corr_higher.iterrows():
#             print('Logtrans 칼럼', trans_col, 'Outlier 처리 칼럼', row_c['col'], row_c['corr_value'])
#             corr_highest = row_c[1]
#             df_processed = log_trans(df[file], trans_col)
#             df_processed = drop_outlier(df_processed, corr_highest, Y_col, yes_value, weight=1.5)
#             result = split_impute_train2(file, df_processed, configs, option='LGBM', logtran=trans_col, out_col=corr_highest)
#             results = results.append(result)
#             print()
# Out:
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.968
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.896 재현율: 0.781
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.75 정확도: 0.982 정밀도: 0.621 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.916 재현율: 0.765
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.746 정확도: 0.982 정밀도: 0.612 재현율: 0.954
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.822 정확도: 0.991 정밀도: 0.888 재현율: 0.765
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.969
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.896 재현율: 0.781
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.916 재현율: 0.765
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.746 정확도: 0.982 정밀도: 0.612 재현율: 0.955
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.822 정확도: 0.991 정밀도: 0.888 재현율: 0.765
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.969
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.896 재현율: 0.781
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.834 정확도: 0.991 정밀도: 0.916 재현율: 0.765
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.624 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.814 정확도: 0.99 정밀도: 0.909 재현율: 0.738
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_max.csv logistic f1 점수: 0.746 정확도: 0.982 정밀도: 0.612 재현율: 0.954
# scaled_MetroPT3(AirCompressor)_max.csv LGBM f1 점수: 0.822 정확도: 0.991 정밀도: 0.888 재현율: 0.765
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.612 재현율: 0.971
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.804 정확도: 0.991 정밀도: 0.958 재현율: 0.693
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.627 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.723 정확도: 0.987 정밀도: 0.941 재현율: 0.587
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.744 정확도: 0.982 정밀도: 0.61 재현율: 0.953
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.802 정확도: 0.99 정밀도: 0.915 재현율: 0.714
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.971
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.804 정확도: 0.991 정밀도: 0.958 재현율: 0.693
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.625 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.723 정확도: 0.987 정밀도: 0.941 재현율: 0.587
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.743 정확도: 0.982 정밀도: 0.609 재현율: 0.951
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.802 정확도: 0.99 정밀도: 0.915 재현율: 0.714
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.615 재현율: 0.972
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.804 정확도: 0.991 정밀도: 0.958 재현율: 0.693
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.723 정확도: 0.987 정밀도: 0.941 재현율: 0.587
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.809 정확도: 0.99 정밀도: 0.944 재현율: 0.707
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_mean.csv logistic f1 점수: 0.744 정확도: 0.982 정밀도: 0.61 재현율: 0.953
# scaled_MetroPT3(AirCompressor)_mean.csv LGBM f1 점수: 0.802 정확도: 0.99 정밀도: 0.915 재현율: 0.714
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.97
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.832 정확도: 0.992 정밀도: 0.949 재현율: 0.74
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.819 정확도: 0.991 정밀도: 0.939 재현율: 0.726
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.744 정확도: 0.982 정밀도: 0.61 재현율: 0.954
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.909 재현율: 0.758
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.612 재현율: 0.971
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.832 정확도: 0.992 정밀도: 0.949 재현율: 0.74
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.819 정확도: 0.991 정밀도: 0.939 재현율: 0.726
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.743 정확도: 0.982 정밀도: 0.61 재현율: 0.951
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.909 재현율: 0.758
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.97
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.832 정확도: 0.992 정밀도: 0.949 재현율: 0.74
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.625 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.819 정확도: 0.991 정밀도: 0.939 재현율: 0.726
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.752 정확도: 0.982 정밀도: 0.626 재현율: 0.944
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.944 재현율: 0.736
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_median.csv logistic f1 점수: 0.744 정확도: 0.982 정밀도: 0.61 재현율: 0.953
# scaled_MetroPT3(AirCompressor)_median.csv LGBM f1 점수: 0.827 정확도: 0.991 정밀도: 0.909 재현율: 0.758
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.751 정확도: 0.982 정밀도: 0.613 재현율: 0.967
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.884 정확도: 0.994 정밀도: 0.956 재현율: 0.823
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.754 정확도: 0.982 정밀도: 0.626 재현율: 0.946
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.834 정확도: 0.992 정밀도: 0.955 재현율: 0.739
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 LPS Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.743 정확도: 0.982 정밀도: 0.61 재현율: 0.95
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.867 정확도: 0.993 정밀도: 0.944 재현율: 0.802
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.75 정확도: 0.982 정밀도: 0.613 재현율: 0.966
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.884 정확도: 0.994 정밀도: 0.956 재현율: 0.823
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.834 정확도: 0.992 정밀도: 0.955 재현율: 0.739
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 Pressure_switch Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.743 정확도: 0.982 정밀도: 0.61 재현율: 0.95
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.867 정확도: 0.993 정밀도: 0.944 재현율: 0.802
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_pressure 0.6235276962761107
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.75 정확도: 0.982 정밀도: 0.613 재현율: 0.966
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.884 정확도: 0.994 정밀도: 0.956 재현율: 0.823
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 DV_eletric 0.3241307266633006
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.834 정확도: 0.992 정밀도: 0.955 재현율: 0.739
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 COMP -0.3192522981597581
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 MPG -0.31346926177742435
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.753 정확도: 0.982 정밀도: 0.626 재현율: 0.945
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.843 정확도: 0.992 정밀도: 0.941 재현율: 0.763
#
# Logtrans 칼럼 Oil_level Outlier 처리 칼럼 Oil_temperature 0.3117552321340872
# scaled_MetroPT3(AirCompressor)_min.csv logistic f1 점수: 0.743 정확도: 0.982 정밀도: 0.61 재현율: 0.95
# scaled_MetroPT3(AirCompressor)_min.csv LGBM f1 점수: 0.867 정확도: 0.993 정밀도: 0.944 재현율: 0.802

# %%
# files = os.listdir(os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/imputed')))
# files = [x for x in files if not x.startswith('draft')]
# files

# df = {}
# for file in files:
#     df[file] = pd.read_csv( os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/imputed', f'{file}')))

# %%
# for file in files:
#     result = split_impute_train2(file, df[file], configs, option='logic', logtran=None, out_col=None)
#     results = results.append(result)

# for file in files:
#     skewed = get_skew_top3(df[file])
#     for idx, row in skewed.iterrows():
#         trans_col = row[0]
#         print('Logtrans 칼럼', trans_col)
#         df_log_processed = log_trans(df[file], trans_col)
#         result = split_impute_train2(file, df_log_processed, configs, option='logic', logtran=trans_col, out_col=None)
#         results = results.append(result)
#         print()

#     df_log_processed = df[file].copy()
#     for idx, row in skewed.iterrows():
#         trans_col = row[0]
#         df_log_processed = log_trans(df_log_processed, trans_col)
#     result = split_impute_train2(file, df_log_processed, configs, option='logic', logtran='combined', out_col=None)

#     results = results.append(result)

    
# yes_value = 1

# for file in files:
#     corr_higher = get_corr_top5(df[file], Y_col, yes_value)

#     for idx_s, row_s in skewed.iterrows():
#         trans_col = row_s[0]    
#         for idx_c, row_c in corr_higher.iterrows():
#             print('Logtrans 칼럼', trans_col, 'Outlier 처리 칼럼', row_c['col'], row_c['corr_value'])
#             corr_highest = row_c[1]
#             df_processed = log_trans(df[file], trans_col)
#             df_processed = drop_outlier(df_processed, corr_highest, Y_col, yes_value, weight=1.5)
#             result = split_impute_train2(file, df_processed, configs, option='logistic', logtran=trans_col, out_col=corr_highest)
#             results = results.append(result)
#             print()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(['dark_background'])

# %%
results_ori = results.reset_index(drop=True)
results_ori['cat'] = results_ori['LogTrans']+':'+results_ori['Outliered'] 
results_ori
# Out:
#                                           File     Model   LogTrans  \
# 0       scaled_MetroPT3(AirCompressor)_max.csv  logistic       None
# 1       scaled_MetroPT3(AirCompressor)_max.csv      LGBM       None
# 2      scaled_MetroPT3(AirCompressor)_mean.csv  logistic       None
# 3      scaled_MetroPT3(AirCompressor)_mean.csv      LGBM       None
# 4    scaled_MetroPT3(AirCompressor)_median.csv  logistic       None
# ..                                         ...       ...        ...
# 155     scaled_MetroPT3(AirCompressor)_min.csv      LGBM  Oil_level
# 156     scaled_MetroPT3(AirCompressor)_min.csv  logistic  Oil_level
# 157     scaled_MetroPT3(AirCompressor)_min.csv      LGBM  Oil_level
# 158     scaled_MetroPT3(AirCompressor)_min.csv  logistic  Oil_level
# 159     scaled_MetroPT3(AirCompressor)_min.csv      LGBM  Oil_level
#
#            Outliered     F1  Accuracy  Precision  Recall  \
# 0               None  0.679     0.975      0.620   0.750
# 1               None  0.722     0.983      0.886   0.609
# 2               None  0.679     0.975      0.620   0.751
# 3               None  0.666     0.982      0.941   0.515
# 4               None  0.679     0.975      0.621   0.750
# ..               ...    ...       ...        ...     ...
# 155             COMP  0.843     0.992      0.941   0.763
# 156              MPG  0.753     0.982      0.626   0.945
# 157              MPG  0.843     0.992      0.941   0.763
# 158  Oil_temperature  0.743     0.982      0.610   0.950
# 159  Oil_temperature  0.867     0.993      0.944   0.802
#
#                            cat
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 155             Oil_level:COMP
# 156              Oil_level:MPG
# 157              Oil_level:MPG
# 158  Oil_level:Oil_temperature
# 159  Oil_level:Oil_temperature
#
# [160 rows x 9 columns]

# %%
results_sorted = results_ori.sort_values(['F1','cat'], ascending=[True,False])#.set_index('cat')
results_sorted
# Out:
#                                         File Model         LogTrans  \
# 3    scaled_MetroPT3(AirCompressor)_mean.csv  LGBM             None
# 17   scaled_MetroPT3(AirCompressor)_mean.csv  LGBM              LPS
# 19   scaled_MetroPT3(AirCompressor)_mean.csv  LGBM  Pressure_switch
# 21   scaled_MetroPT3(AirCompressor)_mean.csv  LGBM        Oil_level
# 23   scaled_MetroPT3(AirCompressor)_mean.csv  LGBM         combined
# ..                                       ...   ...              ...
# 159   scaled_MetroPT3(AirCompressor)_min.csv  LGBM        Oil_level
# 139   scaled_MetroPT3(AirCompressor)_min.csv  LGBM              LPS
# 141   scaled_MetroPT3(AirCompressor)_min.csv  LGBM  Pressure_switch
# 151   scaled_MetroPT3(AirCompressor)_min.csv  LGBM        Oil_level
# 131   scaled_MetroPT3(AirCompressor)_min.csv  LGBM              LPS
#
#            Outliered     F1  Accuracy  Precision  Recall  \
# 3               None  0.666     0.982      0.941   0.515
# 17              None  0.666     0.982      0.941   0.515
# 19              None  0.666     0.982      0.941   0.515
# 21              None  0.666     0.982      0.941   0.515
# 23              None  0.666     0.982      0.941   0.515
# ..               ...    ...       ...        ...     ...
# 159  Oil_temperature  0.867     0.993      0.944   0.802
# 139  Oil_temperature  0.867     0.993      0.944   0.802
# 141      DV_pressure  0.884     0.994      0.956   0.823
# 151      DV_pressure  0.884     0.994      0.956   0.823
# 131      DV_pressure  0.884     0.994      0.956   0.823
#
#                              cat
# 3                            NaN
# 17                           NaN
# 19                           NaN
# 21                           NaN
# 23                           NaN
# ..                           ...
# 159    Oil_level:Oil_temperature
# 139          LPS:Oil_temperature
# 141  Pressure_switch:DV_pressure
# 151        Oil_level:DV_pressure
# 131              LPS:DV_pressure
#
# [160 rows x 9 columns]

# %%
sns.reset_orig()
plt.style.use(['dark_background'])
ax = sns.catplot(x="cat", y="F1", data=results_sorted.iloc[:], kind='point',height=5,aspect=25/6)
sns.set(font_scale = 10)
plt.xticks(rotation=45)
ax.set_xticklabels(size=15)
ax.set_yticklabels(size=15)
plt.xlabel("LogTransformation & OutlierRemoved", size=15)
plt.ylabel("F1 Score", size=15)
plt.show()

# %% [markdown]
# ### PCA

# %%
cur_path = os.getcwd()
parent = os.path.abspath(os.path.join(cur_path, os.pardir))
config_file = os.path.join(parent, os.path.join('config', f'{config_file_name}'))
configs = pd.read_excel(config_file, header=None).set_index(0).T
configs = configs.to_dict('list')
ori_file_name = configs['file_name'][0]
configs['file_name'][0] = os.path.join(parent, os.path.join('data', configs['file_name'][0]))
Y_col = configs['y_col'][0]
# df_initial = read_data(configs)

# df, y_null = y_label_enc(df_initial, configs)
# df_organized, discrete, continuous, categorical = organize_data(df, configs, y_null)
# pipe = make_imputer_pipe(discrete, continuous, categorical)
# df_imputed = do_imputation_whole(df_organized, pipe)
# df_scaled = StandardScaler().fit_transform(df_imputed.drop(columns=Y_col))

# %%
r11 = results.copy()

# %%
from sklearn.decomposition import PCA

Y_COL = configs['y_col'][0]
files = os.listdir(os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/scaled')))
df = {}
for file in files:
    df[file] = pd.read_csv( os.path.join(parent, os.path.join('data_preprocessed', f'{folder_name}/scaled', f'{file}')))

    for n_component in range(2,int(len(df[file].columns)/2)):
        pca = PCA(n_components=n_component)
        pca.fit(df[file].drop(columns=['split', Y_COL]))
        df_pca = pca.transform(df[file].drop(columns=['split', Y_COL]))
        df_pca = pd.DataFrame(df_pca)
        df_pca[Y_COL]=df[file][Y_COL]
        df_pca['split']=df[file]['split']
        print('PCA n_component', n_component)
        result = pca_train_metric2(file, df_pca, configs, option='logic', logtran='PCA', out_col=n_component)
    results = results.append(result)
# Out:
# PCA n_component 2
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 3
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 4
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 5
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 6
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 7
# scaled_MetroPT3(AirCompressor)_max.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 2
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 3
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 4
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 5
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 6
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 7
# scaled_MetroPT3(AirCompressor)_mean.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 2
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 3
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 4
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 5
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 6
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 7
# scaled_MetroPT3(AirCompressor)_median.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 2
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 3
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 4
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 5
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 6
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0
# PCA n_component 7
# scaled_MetroPT3(AirCompressor)_min.csv logic f1 점수: 0.0 정확도: 0.965 정밀도: 0.0 재현율: 0.0

# %%
results_ori2 = results.reset_index(drop=True)
results_ori2['cat'] = results_ori2['LogTrans']+':'+results_ori2['Outliered'].astype(str)
results_sorted = results_ori2.sort_values(['F1','cat'], ascending=[True,False])#.set_index('cat')
results_sorted
# Out:
#                                          File     Model  LogTrans   Outliered  \
# 80     scaled_MetroPT3(AirCompressor)_max.csv     logic       PCA           7
# 81    scaled_MetroPT3(AirCompressor)_mean.csv     logic       PCA           7
# 82  scaled_MetroPT3(AirCompressor)_median.csv     logic       PCA           7
# 83     scaled_MetroPT3(AirCompressor)_min.csv     logic       PCA           7
# 19     scaled_MetroPT3(AirCompressor)_min.csv     logic  combined        None
# ..                                        ...       ...       ...         ...
# 36    scaled_MetroPT3(AirCompressor)_mean.csv  logistic       LPS  DV_eletric
# 37    scaled_MetroPT3(AirCompressor)_mean.csv  logistic       LPS        COMP
# 52  scaled_MetroPT3(AirCompressor)_median.csv  logistic       LPS        COMP
# 67     scaled_MetroPT3(AirCompressor)_min.csv  logistic       LPS        COMP
# 66     scaled_MetroPT3(AirCompressor)_min.csv  logistic       LPS  DV_eletric
#
#        F1  Accuracy  Precision  Recall             cat
# 80  0.000     0.965      0.000   0.000           PCA:7
# 81  0.000     0.965      0.000   0.000           PCA:7
# 82  0.000     0.965      0.000   0.000           PCA:7
# 83  0.000     0.965      0.000   0.000           PCA:7
# 19  0.678     0.975      0.619   0.750   combined:None
# ..    ...       ...        ...     ...             ...
# 36  0.753     0.982      0.627   0.944  LPS:DV_eletric
# 37  0.753     0.982      0.626   0.945        LPS:COMP
# 52  0.753     0.982      0.626   0.944        LPS:COMP
# 67  0.753     0.982      0.626   0.945        LPS:COMP
# 66  0.754     0.982      0.626   0.946  LPS:DV_eletric
#
# [84 rows x 9 columns]

# %%
results_sorted[results_sorted['LogTrans']=='PCA'][results_sorted.columns[3:]]
# Out:
#    Outliered   F1  Accuracy  Precision  Recall    cat
# 80         7  0.0     0.965        0.0     0.0  PCA:7
# 81         7  0.0     0.965        0.0     0.0  PCA:7
# 82         7  0.0     0.965        0.0     0.0  PCA:7
# 83         7  0.0     0.965        0.0     0.0  PCA:7
# 84         7  0.0     0.965        0.0     0.0  PCA:7
# 85         7  0.0     0.965        0.0     0.0  PCA:7
# 86         7  0.0     0.965        0.0     0.0  PCA:7
# 87         7  0.0     0.965        0.0     0.0  PCA:7
# 88         7  0.0     0.965        0.0     0.0  PCA:7
# 89         7  0.0     0.965        0.0     0.0  PCA:7
# 90         7  0.0     0.965        0.0     0.0  PCA:7

# %%
sns.reset_orig()
plt.style.use(['dark_background'])
ax = sns.catplot(x="cat", y="F1", data=results_sorted.iloc[:], kind='point',height=5,aspect=12/5)
sns.set(font_scale = 10)
plt.xticks(rotation=45)
ax.set_xticklabels(size=15)
ax.set_yticklabels(size=15)
plt.xlabel("LogTransformation & OutlierRemoved & PCA", size=15)
plt.ylabel("F1 Score", size=15)
plt.show()

# %% [markdown]
# ### feature importance & permutation importance

# %% [markdown]
# #### Feature Importance

# %%
log_col = 'Pressure_switch'
corr_col = 'H1'
df_processed = log_trans(df_organized, log_col)
df_processed = drop_outlier(df_processed, corr_col, Y_col, yes_value, weight=1.5)
X_train, X_test, y_train, y_test = split_train_test(df_processed, configs)
pipe = make_imputer_pipe(discrete, continuous, categorical)
X_train, X_test, y_train, y_test = do_imputation(X_train, X_test, y_train, y_test, pipe)
model = model_selection('LGBM')
model.fit(X_train, y_train)
scaler = MinMaxScaler()
m_feature_importances = scaler.fit_transform(model.feature_importances_.reshape(-1,1)).reshape(-1)
feature_imp = pd.DataFrame(sorted(zip(m_feature_importances,X_train.columns)), columns=['Value','Feature'])

sns.reset_orig()
plt.style.use(['dark_background'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('LightGBM Features Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Permutaion Feature Importance

# %%
from sklearn.inspection import permutation_importance

p_feature_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=0, n_jobs=2)
scaler = MinMaxScaler()
p_feature_importance = scaler.fit_transform(p_feature_importance.importances_mean.reshape(-1,1)).reshape(-1)

feature_imp = pd.DataFrame(sorted(zip(p_feature_importance,X_test.columns)), columns=['Value','Feature'])
sns.reset_orig()
plt.style.use(['dark_background'])

plt.figure(figsize=(12, 6))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('LightGBM Features Importance (Test Set)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
df_temp = df_imputed.drop(columns=Y_col).copy()
vif["VIF Factor"] = [variance_inflation_factor(df_temp.values, i) for i in range(df_temp.shape[1])]
vif["features"] = df_temp.columns
vif_top5 = vif.sort_values(by='VIF Factor',ascending=False).head(5)
vif_top5
# Out:
#       VIF Factor    features
# 4   1.855321e+07  Reservoirs
# 1   1.854686e+07         TP3
# 10  4.933091e+03         MPG
# 7   1.483248e+03        COMP
# 13  1.235195e+03   Oil_level

# %%
feature_c = pd.DataFrame(continuous, columns=['features'])
feature_c['type'] = 'c'
feature_d = pd.DataFrame(discrete, columns=['features'])
feature_d['type'] = 'd'
feature_ca = pd.DataFrame(categorical, columns=['features'])
feature_ca['type'] = 'ca'
feature_type = pd.concat([feature_c,feature_d,feature_ca]).reset_index(drop=True)
feature_type =vif_top5.merge(feature_type, on='features')
feature_type
# Out:
#      VIF Factor    features type
# 0  1.855321e+07  Reservoirs    c
# 1  1.854686e+07         TP3    c
# 2  4.933091e+03         MPG    d
# 3  1.483248e+03        COMP    d
# 4  1.235195e+03   Oil_level    d

# %%
# base score
r0 = split_impute_train(df_organized, configs, discrete, continuous, categorical, option='logistic', logtran='Base Score', out_col=None)
# Out:
# logistic f1 점수: 0.61 정확도: 0.97 정밀도: 0.63 재현율: 0.59

# %%
c_list = continuous.copy()
c_list.remove(vif_top5.iloc[0,1])
df_temp = df_organized.drop(columns=vif_top5.iloc[0,1])
r1 = split_impute_train(df_temp, configs, discrete, c_list, categorical, option='logistic', logtran=None, out_col=vif_top5.iloc[0,1])
# Out:
# logistic f1 점수: 0.59 정확도: 0.97 정밀도: 0.62 재현율: 0.56

# %%
c_list = continuous.copy()
c_list.remove(vif_top5.iloc[1,1])
df_temp = df_organized.drop(columns=vif_top5.iloc[1,1])
r2 = split_impute_train(df_temp, configs, discrete, c_list, categorical, option='logistic', logtran=None, out_col=vif_top5.iloc[1,1])
# Out:
# logistic f1 점수: 0.62 정확도: 0.97 정밀도: 0.64 재현율: 0.6

# %%
d_list = discrete.copy()
d_list.remove(vif_top5.iloc[2,1])
df_temp = df_organized.drop(columns=vif_top5.iloc[2,1])
r3 = split_impute_train(df_temp, configs, d_list, continuous, categorical, option='logistic', logtran=None, out_col=vif_top5.iloc[2,1])
# Out:
# logistic f1 점수: 0.61 정확도: 0.97 정밀도: 0.64 재현율: 0.59

# %%
c_list = continuous.copy()
c_list.remove(vif_top5.iloc[0,1])
c_list.remove(vif_top5.iloc[1,1])
df_temp = df_organized.drop(columns=[vif_top5.iloc[0,1], vif_top5.iloc[1,1]])
cols = vif_top5.iloc[0,1]+'/'+ vif_top5.iloc[1,1]
r4 = split_impute_train(df_temp, configs, discrete, c_list, categorical, option='logistic', logtran=None, out_col=cols)
# Out:
# logistic f1 점수: 0.65 정확도: 0.98 정밀도: 0.66 재현율: 0.64

# %%
c_list = continuous.copy()
c_list.remove(vif_top5.iloc[0,1])
c_list.remove(vif_top5.iloc[1,1])
d_list = discrete.copy()
d_list.remove(vif_top5.iloc[2,1])
df_temp = df_organized.drop(columns=[vif_top5.iloc[0,1], vif_top5.iloc[1,1], vif_top5.iloc[2,1]])
cols = vif_top5.iloc[0,1]+'/'+ vif_top5.iloc[1,1]+'/'+vif_top5.iloc[2,1]
r5 = split_impute_train(df_temp, configs, d_list, c_list, categorical, option='logistic', logtran=None, out_col=cols)
# Out:
# logistic f1 점수: 0.66 정확도: 0.98 정밀도: 0.66 재현율: 0.65

# %%
pd.concat([r0,r1,r2,r3,r4,r5])
# Out:
#       Model    LogTrans           Outliered    F1  Accuracy  Precision  Recall
# 0  logistic  Base Score                None  0.61      0.97       0.63    0.59
# 0  logistic        None          Reservoirs  0.59      0.97       0.62    0.56
# 0  logistic        None                 TP3  0.62      0.97       0.64    0.60
# 0  logistic        None                 MPG  0.61      0.97       0.64    0.59
# 0  logistic        None      Reservoirs/TP3  0.65      0.98       0.66    0.64
# 0  logistic        None  Reservoirs/TP3/MPG  0.66      0.98       0.66    0.65
